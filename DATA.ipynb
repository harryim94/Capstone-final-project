# %%
#import 
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
import folium # plotting library
print('Libraries imported.')
# Out:
# Libraries imported.

# %%
#We start with grabbing necessary data from foursquare
#First I start with accesing foursquare
CLIENT_ID = 'NUSJGEEUGFOCDQ5WLXUUNFMOTCSXONUX4O5F1SMRQ3RNMNH2' # your Foursquare ID
CLIENT_SECRET = 'I0AA1UCKZWH4YBXA4OKHTYSMHGCJYJVZAABRGJY2LEJXEQ2L' # your Foursquare Secret
ACCESS_TOKEN = 'QMNXDM5FB2ZFYWHNPX2RNOSMMZCJRQIPS33IPKKAWBZ4HYUG' # your FourSquare Access Token
VERSION = '20210130'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: NUSJGEEUGFOCDQ5WLXUUNFMOTCSXONUX4O5F1SMRQ3RNMNH2
# CLIENT_SECRET:I0AA1UCKZWH4YBXA4OKHTYSMHGCJYJVZAABRGJY2LEJXEQ2L

# %%
#set up the location where were you thinking to start? in my case, it's near beaches
latitude =43.6426
longitude =-79.3871
search_query = 'Resturant'
radius = 3000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NUSJGEEUGFOCDQ5WLXUUNFMOTCSXONUX4O5F1SMRQ3RNMNH2&client_secret=I0AA1UCKZWH4YBXA4OKHTYSMHGCJYJVZAABRGJY2LEJXEQ2L&ll=43.6426,-79.3871&oauth_token=QMNXDM5FB2ZFYWHNPX2RNOSMMZCJRQIPS33IPKKAWBZ4HYUG&v=20210130&query=Resturant&radius=3000&limit=30'

# %%
#send the get request and examine the results
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6015b42401ee3039798cad94'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4ad4c05cf964a520dff520e3',
#     'name': '360 Restaurant',
#     'location': {'address': '301 Front St W',
#      'crossStreet': '301 Front St. W',
#      'lat': 43.642537317144566,
#      'lng': -79.38704201569328,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642537317144566,
#        'lng': -79.38704201569328}],
#      'distance': 8,
#      'postalCode': 'M5V 2T6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['301 Front St W (301 Front St. W)',
#       'Toronto ON M5V 2T6']},
#     'categories': [{'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'shortName': 'Wine Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df = json_normalize(venues)
df.head()
# Out:
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                         name  \
# 0  4ad4c05cf964a520dff520e3               360 Restaurant
# 1  4c87c1640dcb8cfa39953d68            Houston Resturant
# 2  5186e81e498e8372ef02cd79            The One Resturant
# 3  4b2a674ef964a52074a824e3      New Treasure Restaurant
# 4  5042aa6ce4b0711880f87242  First Choice Portugese Food
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...  v-1612035108    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1612035108    False
# 2  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1612035108    False
# 3  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1612035108    False
# ...

# %%
#filter the data
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df.columns if col.startswith('location.')] + ['id']
dataframe_filtered = df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                           name             categories          address  \
# 0               360 Restaurant               Wine Bar   301 Front St W
# 1            Houston Resturant             Restaurant              NaN
# 2            The One Resturant    American Restaurant     895 Yonge st
# 3      New Treasure Restaurant     Dim Sum Restaurant  150 Dundas St W
# 4  First Choice Portugese Food  Portuguese Restaurant              NaN
#
#        crossStreet        lat        lng  \
# 0  301 Front St. W  43.642537 -79.387042
# 1              NaN  43.647558 -79.377615
# 2              NaN  43.674629 -79.388451
# 3     at Elizabeth  43.655384 -79.385362
# 4              NaN  43.649551 -79.420170
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.64253731714456...         8    M5V 2T6  CA
# 1  [{'label': 'display', 'lat': 43.64755805, 'lng...       942    M5E 1C7  CA
# ...

# %%
#let's visualize nearby resturants
dataframe_filtered.name
# Out:
# 0                 360 Restaurant
# 1              Houston Resturant
# 2              The One Resturant
# 3        New Treasure Restaurant
# 4    First Choice Portugese Food
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#Let's explore our first competitors
#first competitor
venue_id = '4ad4c05cf964a520dff520e3' # ID of index0 resturant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'like', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'seasonalHours', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4ad4c05cf964a520dff520e3',
#  'name': '360 Restaurant',
#  'contact': {'phone': '4163625411',
#   'formattedPhone': '(416) 362-5411',
#   'twitter': 'tourcntower'},
#  'location': {'address': '301 Front St W',
#   'crossStreet': '301 Front St. W',
#   'lat': 43.642537317144566,
#   'lng': -79.38704201569328,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.642537317144566,
#     'lng': -79.38704201569328}],
#   'postalCode': 'M5V 2T6',
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
# ...

# %%
#rating
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.4

# %%
#2nd competitor
venue_id = '4c87c1640dcb8cfa39953d68' # ID of index1 resturant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'like', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '4c87c1640dcb8cfa39953d68',
#  'name': 'Houston Resturant',
#  'contact': {},
#  'location': {'lat': 43.64755805,
#   'lng': -79.3776149,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.64755805,
#     'lng': -79.3776149}],
#   'postalCode': 'M5E 1C7',
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['Toronto ON M5E 1C7']},
#  'canonicalUrl': 'https://foursquare.com/v/houston-resturant/4c87c1640dcb8cfa39953d68',
#  'categories': [{'id': '4bf58dd8d48988d1c4941735',
#    'name': 'Restaurant',
#    'pluralName': 'Restaurants',
#    'shortName': 'Restaurant',
# ...

# %%
#rating
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
#3rd competitor
venue_id = '5186e81e498e8372ef02cd79' # ID of index2 resturant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'like', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto'])
# {'id': '5186e81e498e8372ef02cd79',
#  'name': 'The One Resturant',
#  'contact': {},
#  'location': {'address': '895 Yonge st',
#   'lat': 43.67462921142578,
#   'lng': -79.3884506225586,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.67462921142578,
#     'lng': -79.3884506225586}],
#   'cc': 'CA',
#   'country': 'Canada',
#   'formattedAddress': ['895 Yonge st']},
#  'canonicalUrl': 'https://foursquare.com/v/the-one-resturant/5186e81e498e8372ef02cd79',
#  'categories': [{'id': '4bf58dd8d48988d14e941735',
#    'name': 'American Restaurant',
#    'pluralName': 'American Restaurants',
#    'shortName': 'American',
# ...

# %%
#rating
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
#4th competitor
venue_id = '4b2a674ef964a52074a824e3' # ID of index3 resturant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'like', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4b2a674ef964a52074a824e3',
#  'name': 'New Treasure Restaurant',
#  'contact': {'phone': '4169773778', 'formattedPhone': '(416) 977-3778'},
#  'location': {'address': '150 Dundas St W',
#   'crossStreet': 'at Elizabeth',
#   'lat': 43.65538444237565,
#   'lng': -79.3853618106867,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.65538444237565,
#     'lng': -79.3853618106867}],
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['150 Dundas St W (at Elizabeth)', 'Toronto ON']},
# ...

# %%
#rating
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.6

# %%
#last competitor
venue_id = '5042aa6ce4b0711880f87242' # ID of index4 resturant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'like', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '5042aa6ce4b0711880f87242',
#  'name': 'First Choice Portugese Food',
#  'contact': {},
#  'location': {'lat': 43.64955085110921,
#   'lng': -79.42017015359258,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.64955085110921,
#     'lng': -79.42017015359258}],
#   'cc': 'CA',
#   'country': 'Canada'},
#  'canonicalUrl': 'https://foursquare.com/v/first-choice-portugese-food/5042aa6ce4b0711880f87242',
#  'categories': [{'id': '4def73e84765ae376e57713a',
#    'name': 'Portuguese Restaurant',
#    'pluralName': 'Portuguese Restaurants',
#    'shortName': 'Portuguese',
# ...

# %%
#rating
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# ## It seems like we need to explore more about 1st and 4th competitor since they have high rating

# %%
#tips for 1st competitor
limit=15
venue_id = '4ad4c05cf964a520dff520e3' # ID of index0 resturant
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION, limit)
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6015bb8bad7912594941176e'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'tips': {'count': 101,
#    'items': [{'id': '5562f899498e363a212157d4',
#      'createdAt': 1432549529,
#      'text': 'Amazing view, a bit pricey but worth it if you are visiting once, and their food is delicious! (I recommend the Half Chicken) You can have 2 courses or 3 courses.',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5562f899498e363a212157d4',
#      'photo': {'id': '5562f89a498ec92a1cf2e21a',
#       'createdAt': 1432549530,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/126628605_I6EbsJvQY8wr8N-8HRz7bAMXh0aYY9f-krrOmF7JzZw.jpg',
#       'width': 1440,
#       'height': 1440,
#       'visibility': 'public'},
# ...

# %%
tips = results['response']['tips']['items']
tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'photo', 'photourl', 'likes', 'like', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered.reindex()
# Out:
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                                                                                                                                  text  \
# 0  Amazing view, a bit pricey but worth it if you are visiting once, and their food is delicious! (I recommend the Half Chicken) You can have 2 courses or 3 courses.
#
# ...

# %% [markdown]
# ### Pricey and only worth if you are visting once
